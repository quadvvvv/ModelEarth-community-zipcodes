# %% [markdown]
# # Export Database
#
# This notebook outlines the steps to export data from a DuckDB database:
#
# 1. Initialize the `DataExporter` class.
# 2. Export data for all ZIP codes and industry levels.
# 3. Verify the export results.
#
# The `DataExporter` class will manage the data extraction and export operations.
#
# **Important:** Only run this notebook if you do not already have the CSV files.
# Otherwise, this notebook should be used for reference only.
# The cell outputs are provided for your reference to understand the expected behavior.

# %%
import os
import logging
import duckdb
from multiprocessing import Pool
from tqdm import tqdm
import query as q
from duck_db_exporter import DataExporter  # Assuming DataExporter is defined in data_exporter.py

# Configure logging
logging.basicConfig(level=logging.INFO)

# %% [markdown]
# ## I. Export Database
# - this is in the jupyterversion, there will also be a script version that be used by github action.

# %% [markdown]
# ### I.(a) Export a Single Annual Data

# %%
# Initialize DataExporter
exporter = DataExporter(
    base_db_path='../zip_data/duck_db_manager/database/',
    threads=4,
    export_dir='../../US/zip',
    industry_levels=[2, 5, 6],  # Specify industry levels if needed
    year=2019  # Specify the year for the data
)

# %%
file_paths = exporter.make_csv()  # No state specified: exports data for all states. You can also specify a specific state to export.
# Out:
# INFO:root:Export for state OK at industry level 2 is finished. 3951 rows have been exported.
# INFO:root:Export for state OK at industry level 5 is finished. 8408 rows have been exported.
# INFO:root:Export for state OK at industry level 6 is finished. 8482 rows have been exported.
# INFO:root:Export for state NC at industry level 2 is finished. 7120 rows have been exported.
# INFO:root:Export for state NC at industry level 5 is finished. 21167 rows have been exported.
# INFO:root:Export for state NC at industry level 6 is finished. 21735 rows have been exported.
# INFO:root:Export for state KS at industry level 2 is finished. 3589 rows have been exported.
# INFO:root:Export for state KS at industry level 5 is finished. 6630 rows have been exported.
# INFO:root:Export for state KS at industry level 6 is finished. 6616 rows have been exported.
# INFO:root:Export for state MN at industry level 2 is finished. 5848 rows have been exported.
# INFO:root:Export for state MN at industry level 5 is finished. 13905 rows have been exported.
# INFO:root:Export for state MN at industry level 6 is finished. 14064 rows have been exported.
# INFO:root:Export for state ID at industry level 2 is finished. 1660 rows have been exported.
# INFO:root:Export for state ID at industry level 5 is finished. 4523 rows have been exported.
# INFO:root:Export for state ID at industry level 6 is finished. 4636 rows have been exported.
# INFO:root:Export for state CA at industry level 2 is finished. 17861 rows have been exported.
# INFO:root:Export for state CA at industry level 5 is finished. 81375 rows have been exported.
# INFO:root:Export for state CA at industry level 6 is finished. 84557 rows have been exported.
# INFO:root:Export for state GA at industry level 2 is finished. 6255 rows have been exported.
# INFO:root:Export for state GA at industry level 5 is finished. 20258 rows have been exported.
# INFO:root:Export for state GA at industry level 6 is finished. 21049 rows have been exported.
# INFO:root:Export for state MA at industry level 2 is finished. 5689 rows have been exported.
# INFO:root:Export for state MA at industry level 5 is finished. 16880 rows have been exported.
# INFO:root:Export for state MA at industry level 6 is finished. 17210 rows have been exported.
# INFO:root:Export for state UT at industry level 2 is finished. 2023 rows have been exported.
# INFO:root:Export for state UT at industry level 5 is finished. 7546 rows have been exported.
# INFO:root:Export for state UT at industry level 6 is finished. 7806 rows have been exported.
# INFO:root:Export for state NV at industry level 2 is finished. 1567 rows have been exported.
# INFO:root:Export for state NV at industry level 5 is finished. 6113 rows have been exported.
# INFO:root:Export for state NV at industry level 6 is finished. 6317 rows have been exported.
# INFO:root:Export for state SD at industry level 2 is finished. 1431 rows have been exported.
# INFO:root:Export for state SD at industry level 5 is finished. 2343 rows have been exported.
# INFO:root:Export for state SD at industry level 6 is finished. 2323 rows have been exported.
# INFO:root:Export for state WA at industry level 2 is finished. 5078 rows have been exported.
# INFO:root:Export for state WA at industry level 5 is finished. 17666 rows have been exported.
# INFO:root:Export for state WA at industry level 6 is finished. 18383 rows have been exported.
# INFO:root:Export for state ME at industry level 2 is finished. 2484 rows have been exported.
# INFO:root:Export for state ME at industry level 5 is finished. 3619 rows have been exported.
# INFO:root:Export for state ME at industry level 6 is finished. 3599 rows have been exported.
# INFO:root:Export for state KY at industry level 2 is finished. 3599 rows have been exported.
# INFO:root:Export for state KY at industry level 5 is finished. 8109 rows have been exported.
# INFO:root:Export for state KY at industry level 6 is finished. 8197 rows have been exported.
# INFO:root:Export for state NH at industry level 2 is finished. 1889 rows have been exported.
# INFO:root:Export for state NH at industry level 5 is finished. 3426 rows have been exported.
# INFO:root:Export for state NH at industry level 6 is finished. 3432 rows have been exported.
# INFO:root:Export for state CT at industry level 2 is finished. 2974 rows have been exported.
# INFO:root:Export for state CT at industry level 5 is finished. 8308 rows have been exported.
# INFO:root:Export for state CT at industry level 6 is finished. 8424 rows have been exported.
# INFO:root:Export for state RI at industry level 2 is finished. 794 rows have been exported.
# INFO:root:Export for state RI at industry level 5 is finished. 2761 rows have been exported.
# INFO:root:Export for state RI at industry level 6 is finished. 2826 rows have been exported.
# INFO:root:Export for state VA at industry level 2 is finished. 6335 rows have been exported.
# INFO:root:Export for state VA at industry level 5 is finished. 17273 rows have been exported.
# INFO:root:Export for state VA at industry level 6 is finished. 17988 rows have been exported.
# INFO:root:Export for state NM at industry level 2 is finished. 1515 rows have been exported.
# INFO:root:Export for state NM at industry level 5 is finished. 3846 rows have been exported.
# INFO:root:Export for state NM at industry level 6 is finished. 3927 rows have been exported.
# INFO:root:Export for state MO at industry level 2 is finished. 5732 rows have been exported.
# INFO:root:Export for state MO at industry level 5 is finished. 13028 rows have been exported.
# INFO:root:Export for state MO at industry level 6 is finished. 13104 rows have been exported.
# INFO:root:Export for state OR at industry level 2 is finished. 3149 rows have been exported.
# INFO:root:Export for state OR at industry level 5 is finished. 10702 rows have been exported.
# INFO:root:Export for state OR at industry level 6 is finished. 11047 rows have been exported.
# INFO:root:Export for state CO at industry level 2 is finished. 4259 rows have been exported.
# INFO:root:Export for state CO at industry level 5 is finished. 15244 rows have been exported.
# INFO:root:Export for state CO at industry level 6 is finished. 15797 rows have been exported.
# INFO:root:Export for state AZ at industry level 2 is finished. 3548 rows have been exported.
# INFO:root:Export for state AZ at industry level 5 is finished. 13109 rows have been exported.
# INFO:root:Export for state AZ at industry level 6 is finished. 13551 rows have been exported.
# INFO:root:Export for state MD at industry level 2 is finished. 3924 rows have been exported.
# INFO:root:Export for state MD at industry level 5 is finished. 12183 rows have been exported.
# INFO:root:Export for state MD at industry level 6 is finished. 12578 rows have been exported.
# INFO:root:Export for state TN at industry level 2 is finished. 4551 rows have been exported.
# INFO:root:Export for state TN at industry level 5 is finished. 12181 rows have been exported.
# INFO:root:Export for state TN at industry level 6 is finished. 12410 rows have been exported.
# INFO:root:Export for state SC at industry level 2 is finished. 3437 rows have been exported.
# INFO:root:Export for state SC at industry level 5 is finished. 9818 rows have been exported.
# INFO:root:Export for state SC at industry level 6 is finished. 10095 rows have been exported.
# INFO:root:Export for state IA at industry level 2 is finished. 4598 rows have been exported.
# INFO:root:Export for state IA at industry level 5 is finished. 7073 rows have been exported.
# INFO:root:Export for state IA at industry level 6 is finished. 7036 rows have been exported.
# INFO:root:Export for state ND at industry level 2 is finished. 1329 rows have been exported.
# INFO:root:Export for state ND at industry level 5 is finished. 2053 rows have been exported.
# INFO:root:Export for state ND at industry level 6 is finished. 2053 rows have been exported.
# INFO:root:Export for state PA at industry level 2 is finished. 11705 rows have been exported.
# INFO:root:Export for state PA at industry level 5 is finished. 27144 rows have been exported.
# INFO:root:Export for state PA at industry level 6 is finished. 27404 rows have been exported.
# INFO:root:Export for state OH at industry level 2 is finished. 8743 rows have been exported.
# INFO:root:Export for state OH at industry level 5 is finished. 23197 rows have been exported.
# INFO:root:Export for state OH at industry level 6 is finished. 23220 rows have been exported.
# INFO:root:Export for state IN at industry level 2 is finished. 5425 rows have been exported.
# INFO:root:Export for state IN at industry level 5 is finished. 13573 rows have been exported.
# INFO:root:Export for state IN at industry level 6 is finished. 13528 rows have been exported.
# INFO:root:Export for state NE at industry level 2 is finished. 2749 rows have been exported.
# INFO:root:Export for state NE at industry level 5 is finished. 4914 rows have been exported.
# INFO:root:Export for state NE at industry level 6 is finished. 4900 rows have been exported.
# INFO:root:Export for state WI at industry level 2 is finished. 5888 rows have been exported.
# INFO:root:Export for state WI at industry level 5 is finished. 13290 rows have been exported.
# INFO:root:Export for state WI at industry level 6 is finished. 13150 rows have been exported.
# INFO:root:Export for state LA at industry level 2 is finished. 3893 rows have been exported.
# INFO:root:Export for state LA at industry level 5 is finished. 9565 rows have been exported.
# INFO:root:Export for state LA at industry level 6 is finished. 9693 rows have been exported.
# INFO:root:Export for state HI at industry level 2 is finished. 803 rows have been exported.
# INFO:root:Export for state HI at industry level 5 is finished. 2826 rows have been exported.
# INFO:root:Export for state HI at industry level 6 is finished. 2927 rows have been exported.
# INFO:root:Export for state DC at industry level 2 is finished. 483 rows have been exported.
# INFO:root:Export for state DC at industry level 5 is finished. 1653 rows have been exported.
# INFO:root:Export for state DC at industry level 6 is finished. 1794 rows have been exported.
# INFO:root:Export for state AR at industry level 2 is finished. 2911 rows have been exported.
# INFO:root:Export for state AR at industry level 5 is finished. 5760 rows have been exported.
# INFO:root:Export for state AR at industry level 6 is finished. 5803 rows have been exported.
# INFO:root:Export for state TX at industry level 2 is finished. 16876 rows have been exported.
# INFO:root:Export for state TX at industry level 5 is finished. 52566 rows have been exported.
# INFO:root:Export for state TX at industry level 6 is finished. 54386 rows have been exported.
# INFO:root:Export for state WV at industry level 2 is finished. 2287 rows have been exported.
# INFO:root:Export for state WV at industry level 5 is finished. 2889 rows have been exported.
# INFO:root:Export for state WV at industry level 6 is finished. 2839 rows have been exported.
# INFO:root:Export for state AK at industry level 2 is finished. 900 rows have been exported.
# INFO:root:Export for state AK at industry level 5 is finished. 1970 rows have been exported.
# INFO:root:Export for state AK at industry level 6 is finished. 2016 rows have been exported.
# INFO:root:Export for state FL at industry level 2 is finished. 11876 rows have been exported.
# INFO:root:Export for state FL at industry level 5 is finished. 51600 rows have been exported.
# INFO:root:Export for state FL at industry level 6 is finished. 53501 rows have been exported.
# INFO:root:Export for state VT at industry level 2 is finished. 1365 rows have been exported.
# INFO:root:Export for state VT at industry level 5 is finished. 1723 rows have been exported.
# INFO:root:Export for state VT at industry level 6 is finished. 1693 rows have been exported.
# INFO:root:Export for state NotSpecified at industry level 2 is finished. 17 rows have been exported.
# INFO:root:Export for state NotSpecified at industry level 5 is finished. 210 rows have been exported.
# INFO:root:Export for state NotSpecified at industry level 6 is finished. 242 rows have been exported.
# INFO:root:Export for state MI at industry level 2 is finished. 7839 rows have been exported.
# INFO:root:Export for state MI at industry level 5 is finished. 20566 rows have been exported.
# INFO:root:Export for state MI at industry level 6 is finished. 20593 rows have been exported.
# INFO:root:Export for state AL at industry level 2 is finished. 4369 rows have been exported.
# INFO:root:Export for state AL at industry level 5 is finished. 8757 rows have been exported.
# INFO:root:Export for state AL at industry level 6 is finished. 8801 rows have been exported.
# INFO:root:Export for state MS at industry level 2 is finished. 2711 rows have been exported.
# INFO:root:Export for state MS at industry level 5 is finished. 5267 rows have been exported.
# INFO:root:Export for state MS at industry level 6 is finished. 5244 rows have been exported.
# INFO:root:Export for state WY at industry level 2 is finished. 901 rows have been exported.
# INFO:root:Export for state WY at industry level 5 is finished. 1972 rows have been exported.
# INFO:root:Export for state WY at industry level 6 is finished. 2008 rows have been exported.
# INFO:root:Export for state IL at industry level 2 is finished. 9106 rows have been exported.
# INFO:root:Export for state IL at industry level 5 is finished. 27482 rows have been exported.
# INFO:root:Export for state IL at industry level 6 is finished. 28166 rows have been exported.
# INFO:root:Export for state NY at industry level 2 is finished. 13894 rows have been exported.
# INFO:root:Export for state NY at industry level 5 is finished. 43157 rows have been exported.
# INFO:root:Export for state NY at industry level 6 is finished. 44873 rows have been exported.
# INFO:root:Export for state NJ at industry level 2 is finished. 6641 rows have been exported.
# INFO:root:Export for state NJ at industry level 5 is finished. 20985 rows have been exported.
# INFO:root:Export for state NJ at industry level 6 is finished. 21881 rows have been exported.
# INFO:root:Export for state MT at industry level 2 is finished. 1616 rows have been exported.
# INFO:root:Export for state MT at industry level 5 is finished. 3402 rows have been exported.
# INFO:root:Export for state MT at industry level 6 is finished. 3460 rows have been exported.
# INFO:root:Export for state DE at industry level 2 is finished. 649 rows have been exported.
# INFO:root:Export for state DE at industry level 5 is finished. 2320 rows have been exported.
# INFO:root:Export for state DE at industry level 6 is finished. 2412 rows have been exported.
# INFO:root:Total rows exported for Year 2019: 1649947

# %% [markdown]
# ### I.(b) Export All Annual Data in a Single Run

# %%
export_results = {}
for year in range(2012, 2023):
    # Initialize DataExporter
    exporter = DataExporter(
        base_db_path='../zip_data/duck_db_manager/database/',
        threads=4,
        export_dir='../../US/zip',
        industry_levels=[2, 5, 6],  # Specify industry levels if needed
        year=year  # Specify the year for the data
    )
    # Export data for all states
    export_results[year] = exporter.make_csv()
# Out:
# INFO:root:Export for state RI at industry level 2 is finished. 1072 rows have been exported.
# INFO:root:Export for state RI at industry level 5 is finished. 9405 rows have been exported.
# INFO:root:Export for state RI at industry level 6 is finished. 10413 rows have been exported.
# INFO:root:Export for state SD at industry level 2 is finished. 2866 rows have been exported.
# INFO:root:Export for state SD at industry level 5 is finished. 11782 rows have been exported.
# INFO:root:Export for state SD at industry level 6 is finished. 12593 rows have been exported.
# INFO:root:Export for state CA at industry level 2 is finished. 25624 rows have been exported.
# INFO:root:Export for state CA at industry level 5 is finished. 225341 rows have been exported.
# INFO:root:Export for state CA at industry level 6 is finished. 254130 rows have been exported.
# INFO:root:Export for state MA at industry level 2 is finished. 7653 rows have been exported.
# INFO:root:Export for state MA at industry level 5 is finished. 60058 rows have been exported.
# INFO:root:Export for state MA at industry level 6 is finished. 66379 rows have been exported.
# INFO:root:Export for state CT at industry level 2 is finished. 4157 rows have been exported.
# INFO:root:Export for state CT at industry level 5 is finished. 31487 rows have been exported.
# INFO:root:Export for state CT at industry level 6 is finished. 34773 rows have been exported.
# INFO:root:Export for state WA at industry level 2 is finished. 7351 rows have been exported.
# INFO:root:Export for state WA at industry level 5 is finished. 55428 rows have been exported.
# INFO:root:Export for state WA at industry level 6 is finished. 61647 rows have been exported.
# INFO:root:Export for state NH at industry level 2 is finished. 2953 rows have been exported.
# INFO:root:Export for state NH at industry level 5 is finished. 16217 rows have been exported.
# INFO:root:Export for state NH at industry level 6 is finished. 17654 rows have been exported.
# INFO:root:Export for state KY at industry level 2 is finished. 6553 rows have been exported.
# INFO:root:Export for state KY at industry level 5 is finished. 34506 rows have been exported.
# INFO:root:Export for state KY at industry level 6 is finished. 37503 rows have been exported.
# INFO:root:Export for state GA at industry level 2 is finished. 9355 rows have been exported.
# INFO:root:Export for state GA at industry level 5 is finished. 66470 rows have been exported.
# INFO:root:Export for state GA at industry level 6 is finished. 73426 rows have been exported.
# INFO:root:Export for state ME at industry level 2 is finished. 4291 rows have been exported.
# INFO:root:Export for state ME at industry level 5 is finished. 18909 rows have been exported.
# INFO:root:Export for state ME at industry level 6 is finished. 20273 rows have been exported.
# INFO:root:Export for state NV at industry level 2 is finished. 2328 rows have been exported.
# INFO:root:Export for state NV at industry level 5 is finished. 17214 rows have been exported.
# INFO:root:Export for state NV at industry level 6 is finished. 19266 rows have been exported.
# INFO:root:Export for state UT at industry level 2 is finished. 2970 rows have been exported.
# INFO:root:Export for state UT at industry level 5 is finished. 21953 rows have been exported.
# INFO:root:Export for state UT at industry level 6 is finished. 24652 rows have been exported.
# INFO:root:Export for state ID at industry level 2 is finished. 2745 rows have been exported.
# INFO:root:Export for state ID at industry level 5 is finished. 15685 rows have been exported.
# INFO:root:Export for state ID at industry level 6 is finished. 17229 rows have been exported.
# INFO:root:Export for state OK at industry level 2 is finished. 6627 rows have been exported.
# INFO:root:Export for state OK at industry level 5 is finished. 35235 rows have been exported.
# INFO:root:Export for state OK at industry level 6 is finished. 38271 rows have been exported.
# INFO:root:Export for state NC at industry level 2 is finished. 10924 rows have been exported.
# INFO:root:Export for state NC at industry level 5 is finished. 74058 rows have been exported.
# INFO:root:Export for state NC at industry level 6 is finished. 81352 rows have been exported.
# INFO:root:Export for state MN at industry level 2 is finished. 9286 rows have been exported.
# INFO:root:Export for state MN at industry level 5 is finished. 58250 rows have been exported.
# INFO:root:Export for state MN at industry level 6 is finished. 63449 rows have been exported.
# INFO:root:Export for state KS at industry level 2 is finished. 6449 rows have been exported.
# INFO:root:Export for state KS at industry level 5 is finished. 31753 rows have been exported.
# INFO:root:Export for state KS at industry level 6 is finished. 34293 rows have been exported.
# INFO:root:Export for state MO at industry level 2 is finished. 9675 rows have been exported.
# INFO:root:Export for state MO at industry level 5 is finished. 55409 rows have been exported.
# INFO:root:Export for state MO at industry level 6 is finished. 60293 rows have been exported.
# INFO:root:Export for state NM at industry level 2 is finished. 2895 rows have been exported.
# INFO:root:Export for state NM at industry level 5 is finished. 14961 rows have been exported.
# INFO:root:Export for state NM at industry level 6 is finished. 16487 rows have been exported.
# INFO:root:Export for state VA at industry level 2 is finished. 10213 rows have been exported.
# INFO:root:Export for state VA at industry level 5 is finished. 62301 rows have been exported.
# INFO:root:Export for state VA at industry level 6 is finished. 68791 rows have been exported.
# INFO:root:Export for state OR at industry level 2 is finished. 4724 rows have been exported.
# INFO:root:Export for state OR at industry level 5 is finished. 34412 rows have been exported.
# INFO:root:Export for state OR at industry level 6 is finished. 38190 rows have been exported.
# INFO:root:Export for state MD at industry level 2 is finished. 5659 rows have been exported.
# INFO:root:Export for state MD at industry level 5 is finished. 41040 rows have been exported.
# INFO:root:Export for state MD at industry level 6 is finished. 45699 rows have been exported.
# INFO:root:Export for state CO at industry level 2 is finished. 6255 rows have been exported.
# INFO:root:Export for state CO at industry level 5 is finished. 45311 rows have been exported.
# INFO:root:Export for state CO at industry level 6 is finished. 50655 rows have been exported.
# INFO:root:Export for state AZ at industry level 2 is finished. 5269 rows have been exported.
# INFO:root:Export for state AZ at industry level 5 is finished. 39368 rows have been exported.
# INFO:root:Export for state AZ at industry level 6 is finished. 44064 rows have been exported.
# INFO:root:Export for state TX at industry level 2 is finished. 24951 rows have been exported.
# INFO:root:Export for state TX at industry level 5 is finished. 172190 rows have been exported.
# INFO:root:Export for state TX at industry level 6 is finished. 190283 rows have been exported.
# INFO:root:Export for state WV at industry level 2 is finished. 4855 rows have been exported.
# INFO:root:Export for state WV at industry level 5 is finished. 17945 rows have been exported.
# INFO:root:Export for state WV at industry level 6 is finished. 19185 rows have been exported.
# INFO:root:Export for state AR at industry level 2 is finished. 5337 rows have been exported.
# INFO:root:Export for state AR at industry level 5 is finished. 26021 rows have been exported.
# INFO:root:Export for state AR at industry level 6 is finished. 28048 rows have been exported.
# INFO:root:Export for state FL at industry level 2 is finished. 15954 rows have been exported.
# INFO:root:Export for state FL at industry level 5 is finished. 143712 rows have been exported.
# INFO:root:Export for state FL at industry level 6 is finished. 161442 rows have been exported.
# INFO:root:Export for state AK at industry level 2 is finished. 1727 rows have been exported.
# INFO:root:Export for state AK at industry level 5 is finished. 7692 rows have been exported.
# INFO:root:Export for state AK at industry level 6 is finished. 8360 rows have been exported.
# INFO:root:Export for state VT at industry level 2 is finished. 2654 rows have been exported.
# INFO:root:Export for state VT at industry level 5 is finished. 10932 rows have been exported.
# INFO:root:Export for state VT at industry level 6 is finished. 11669 rows have been exported.
# INFO:root:Export for state NotSpecified at industry level 2 is finished. 18 rows have been exported.
# INFO:root:Export for state NotSpecified at industry level 5 is finished. 237 rows have been exported.
# INFO:root:Export for state NotSpecified at industry level 6 is finished. 278 rows have been exported.
# INFO:root:Export for state AL at industry level 2 is finished. 7222 rows have been exported.
# INFO:root:Export for state AL at industry level 5 is finished. 39464 rows have been exported.
# INFO:root:Export for state AL at industry level 6 is finished. 42646 rows have been exported.
# INFO:root:Export for state IL at industry level 2 is finished. 14281 rows have been exported.
# INFO:root:Export for state IL at industry level 5 is finished. 99855 rows have been exported.
# INFO:root:Export for state IL at industry level 6 is finished. 110383 rows have been exported.
# INFO:root:Export for state NY at industry level 2 is finished. 20671 rows have been exported.
# INFO:root:Export for state NY at industry level 5 is finished. 144913 rows have been exported.
# INFO:root:Export for state NY at industry level 6 is finished. 160265 rows have been exported.
# INFO:root:Export for state MT at industry level 2 is finished. 3014 rows have been exported.
# INFO:root:Export for state MT at industry level 5 is finished. 13968 rows have been exported.
# INFO:root:Export for state MT at industry level 6 is finished. 15152 rows have been exported.
# INFO:root:Export for state MI at industry level 2 is finished. 11902 rows have been exported.
# INFO:root:Export for state MI at industry level 5 is finished. 81653 rows have been exported.
# INFO:root:Export for state MI at industry level 6 is finished. 89887 rows have been exported.
# INFO:root:Export for state NJ at industry level 2 is finished. 8555 rows have been exported.
# INFO:root:Export for state NJ at industry level 5 is finished. 74600 rows have been exported.
# INFO:root:Export for state NJ at industry level 6 is finished. 82801 rows have been exported.
# INFO:root:Export for state WY at industry level 2 is finished. 1542 rows have been exported.
# INFO:root:Export for state WY at industry level 5 is finished. 7926 rows have been exported.
# INFO:root:Export for state WY at industry level 6 is finished. 8614 rows have been exported.
# INFO:root:Export for state MS at industry level 2 is finished. 4796 rows have been exported.
# INFO:root:Export for state MS at industry level 5 is finished. 24159 rows have been exported.
# INFO:root:Export for state MS at industry level 6 is finished. 26063 rows have been exported.
# INFO:root:Export for state DE at industry level 2 is finished. 916 rows have been exported.
# INFO:root:Export for state DE at industry level 5 is finished. 7350 rows have been exported.
# INFO:root:Export for state DE at industry level 6 is finished. 8168 rows have been exported.
# INFO:root:Export for state PA at industry level 2 is finished. 18741 rows have been exported.
# INFO:root:Export for state PA at industry level 5 is finished. 114602 rows have been exported.
# INFO:root:Export for state PA at industry level 6 is finished. 125142 rows have been exported.
# INFO:root:Export for state IA at industry level 2 is finished. 8510 rows have been exported.
# INFO:root:Export for state IA at industry level 5 is finished. 38612 rows have been exported.
# INFO:root:Export for state IA at industry level 6 is finished. 41138 rows have been exported.
# INFO:root:Export for state SC at industry level 2 is finished. 5290 rows have been exported.
# INFO:root:Export for state SC at industry level 5 is finished. 34722 rows have been exported.
# INFO:root:Export for state SC at industry level 6 is finished. 38092 rows have been exported.
# INFO:root:Export for state TN at industry level 2 is finished. 7178 rows have been exported.
# INFO:root:Export for state TN at industry level 5 is finished. 46251 rows have been exported.
# INFO:root:Export for state TN at industry level 6 is finished. 50530 rows have been exported.
# INFO:root:Export for state ND at industry level 2 is finished. 2891 rows have been exported.
# INFO:root:Export for state ND at industry level 5 is finished. 10586 rows have been exported.
# INFO:root:Export for state ND at industry level 6 is finished. 11233 rows have been exported.
# INFO:root:Export for state OH at industry level 2 is finished. 13195 rows have been exported.
# INFO:root:Export for state OH at industry level 5 is finished. 92090 rows have been exported.
# INFO:root:Export for state OH at industry level 6 is finished. 101349 rows have been exported.
# INFO:root:Export for state NE at industry level 2 is finished. 5002 rows have been exported.
# INFO:root:Export for state NE at industry level 5 is finished. 22974 rows have been exported.
# INFO:root:Export for state NE at industry level 6 is finished. 24683 rows have been exported.
# INFO:root:Export for state IN at industry level 2 is finished. 8535 rows have been exported.
# INFO:root:Export for state IN at industry level 5 is finished. 55454 rows have been exported.
# INFO:root:Export for state IN at industry level 6 is finished. 60659 rows have been exported.
# INFO:root:Export for state WI at industry level 2 is finished. 9055 rows have been exported.
# INFO:root:Export for state WI at industry level 5 is finished. 57450 rows have been exported.
# INFO:root:Export for state WI at industry level 6 is finished. 62493 rows have been exported.
# INFO:root:Export for state DC at industry level 2 is finished. 907 rows have been exported.
# INFO:root:Export for state DC at industry level 5 is finished. 4069 rows have been exported.
# INFO:root:Export for state DC at industry level 6 is finished. 4654 rows have been exported.
# INFO:root:Export for state LA at industry level 2 is finished. 6568 rows have been exported.
# INFO:root:Export for state LA at industry level 5 is finished. 37138 rows have been exported.
# INFO:root:Export for state LA at industry level 6 is finished. 40548 rows have been exported.
# INFO:root:Export for state HI at industry level 2 is finished. 1237 rows have been exported.
# INFO:root:Export for state HI at industry level 5 is finished. 8603 rows have been exported.
# INFO:root:Export for state HI at industry level 6 is finished. 9480 rows have been exported.
# INFO:root:Total rows exported for Year 2012: 5569846
# INFO:root:Export for state RI at industry level 2 is finished. 1073 rows have been exported.
# INFO:root:Export for state RI at industry level 5 is finished. 9294 rows have been exported.
# INFO:root:Export for state RI at industry level 6 is finished. 10302 rows have been exported.
# INFO:root:Export for state SD at industry level 2 is finished. 2885 rows have been exported.
# INFO:root:Export for state SD at industry level 5 is finished. 11790 rows have been exported.
# INFO:root:Export for state SD at industry level 6 is finished. 12636 rows have been exported.
# INFO:root:Export for state CA at industry level 2 is finished. 25766 rows have been exported.
# INFO:root:Export for state CA at industry level 5 is finished. 224825 rows have been exported.
# INFO:root:Export for state CA at industry level 6 is finished. 253566 rows have been exported.
# INFO:root:Export for state MA at industry level 2 is finished. 7724 rows have been exported.
# INFO:root:Export for state MA at industry level 5 is finished. 60148 rows have been exported.
# INFO:root:Export for state MA at industry level 6 is finished. 66472 rows have been exported.
# INFO:root:Export for state CT at industry level 2 is finished. 4179 rows have been exported.
# INFO:root:Export for state CT at industry level 5 is finished. 31437 rows have been exported.
# INFO:root:Export for state CT at industry level 6 is finished. 34700 rows have been exported.
# INFO:root:Export for state WA at industry level 2 is finished. 7379 rows have been exported.
# INFO:root:Export for state WA at industry level 5 is finished. 55241 rows have been exported.
# INFO:root:Export for state WA at industry level 6 is finished. 61443 rows have been exported.
# INFO:root:Export for state NH at industry level 2 is finished. 2974 rows have been exported.
# INFO:root:Export for state NH at industry level 5 is finished. 16155 rows have been exported.
# INFO:root:Export for state NH at industry level 6 is finished. 17597 rows have been exported.
# INFO:root:Export for state KY at industry level 2 is finished. 6658 rows have been exported.
# INFO:root:Export for state KY at industry level 5 is finished. 34561 rows have been exported.
# INFO:root:Export for state KY at industry level 6 is finished. 37546 rows have been exported.
# INFO:root:Export for state GA at industry level 2 is finished. 9387 rows have been exported.
# INFO:root:Export for state GA at industry level 5 is finished. 66273 rows have been exported.
# INFO:root:Export for state GA at industry level 6 is finished. 73267 rows have been exported.
# INFO:root:Export for state ME at industry level 2 is finished. 4330 rows have been exported.
# INFO:root:Export for state ME at industry level 5 is finished. 18864 rows have been exported.
# INFO:root:Export for state ME at industry level 6 is finished. 20210 rows have been exported.
# INFO:root:Export for state NV at industry level 2 is finished. 2341 rows have been exported.
# INFO:root:Export for state NV at industry level 5 is finished. 17222 rows have been exported.
# INFO:root:Export for state NV at industry level 6 is finished. 19294 rows have been exported.
# INFO:root:Export for state UT at industry level 2 is finished. 3006 rows have been exported.
# INFO:root:Export for state UT at industry level 5 is finished. 22156 rows have been exported.
# INFO:root:Export for state UT at industry level 6 is finished. 24857 rows have been exported.
# INFO:root:Export for state TX at industry level 2 is finished. 25106 rows have been exported.
# INFO:root:Export for state TX at industry level 5 is finished. 173116 rows have been exported.
# INFO:root:Export for state TX at industry level 6 is finished. 191539 rows have been exported.
# INFO:root:Export for state WV at industry level 2 is finished. 4857 rows have been exported.
# INFO:root:Export for state WV at industry level 5 is finished. 17736 rows have been exported.
# INFO:root:Export for state WV at industry level 6 is finished. 18981 rows have been exported.
# INFO:root:Export for state AR at industry level 2 is finished. 5333 rows have been exported.
# INFO:root:Export for state AR at industry level 5 is finished. 25943 rows have been exported.
# INFO:root:Export for state AR at industry level 6 is finished. 27980 rows have been exported.
# INFO:root:Export for state FL at industry level 2 is finished. 16149 rows have been exported.
# INFO:root:Export for state FL at industry level 5 is finished. 144474 rows have been exported.
# INFO:root:Export for state FL at industry level 6 is finished. 162508 rows have been exported.
# INFO:root:Export for state AK at industry level 2 is finished. 1726 rows have been exported.
# INFO:root:Export for state AK at industry level 5 is finished. 7641 rows have been exported.
# INFO:root:Export for state AK at industry level 6 is finished. 8295 rows have been exported.
# INFO:root:Export for state VT at industry level 2 is finished. 2670 rows have been exported.
# INFO:root:Export for state VT at industry level 5 is finished. 10836 rows have been exported.
# INFO:root:Export for state VT at industry level 6 is finished. 11544 rows have been exported.
# INFO:root:Export for state NotSpecified at industry level 2 is finished. 18 rows have been exported.
# INFO:root:Export for state NotSpecified at industry level 5 is finished. 233 rows have been exported.
# INFO:root:Export for state NotSpecified at industry level 6 is finished. 276 rows have been exported.
# INFO:root:Export for state MD at industry level 2 is finished. 5666 rows have been exported.
# INFO:root:Export for state MD at industry level 5 is finished. 40931 rows have been exported.
# INFO:root:Export for state MD at industry level 6 is finished. 45618 rows have been exported.
# INFO:root:Export for state CO at industry level 2 is finished. 6302 rows have been exported.
# INFO:root:Export for state CO at industry level 5 is finished. 45368 rows have been exported.
# INFO:root:Export for state CO at industry level 6 is finished. 50719 rows have been exported.
# INFO:root:Export for state AZ at industry level 2 is finished. 5303 rows have been exported.
# INFO:root:Export for state AZ at industry level 5 is finished. 39496 rows have been exported.
# INFO:root:Export for state AZ at industry level 6 is finished. 44193 rows have been exported.
# INFO:root:Export for state ID at industry level 2 is finished. 2730 rows have been exported.
# INFO:root:Export for state ID at industry level 5 is finished. 15729 rows have been exported.
# INFO:root:Export for state ID at industry level 6 is finished. 17267 rows have been exported.
# INFO:root:Export for state OK at industry level 2 is finished. 6678 rows have been exported.
# INFO:root:Export for state OK at industry level 5 is finished. 35235 rows have been exported.
# INFO:root:Export for state OK at industry level 6 is finished. 38260 rows have been exported.
# INFO:root:Export for state NC at industry level 2 is finished. 10934 rows have been exported.
# INFO:root:Export for state NC at industry level 5 is finished. 73721 rows have been exported.
# INFO:root:Export for state NC at industry level 6 is finished. 80980 rows have been exported.
# INFO:root:Export for state MN at industry level 2 is finished. 9344 rows have been exported.
# INFO:root:Export for state MN at industry level 5 is finished. 58111 rows have been exported.
# INFO:root:Export for state MN at industry level 6 is finished. 63407 rows have been exported.
# INFO:root:Export for state KS at industry level 2 is finished. 6466 rows have been exported.
# INFO:root:Export for state KS at industry level 5 is finished. 31539 rows have been exported.
# INFO:root:Export for state KS at industry level 6 is finished. 34066 rows have been exported.
# INFO:root:Export for state OH at industry level 2 is finished. 13208 rows have been exported.
# INFO:root:Export for state OH at industry level 5 is finished. 91769 rows have been exported.
# INFO:root:Export for state OH at industry level 6 is finished. 100978 rows have been exported.
# INFO:root:Export for state NE at industry level 2 is finished. 5018 rows have been exported.
# INFO:root:Export for state NE at industry level 5 is finished. 23039 rows have been exported.
# INFO:root:Export for state NE at industry level 6 is finished. 24754 rows have been exported.
# INFO:root:Export for state IN at industry level 2 is finished. 8573 rows have been exported.
# INFO:root:Export for state IN at industry level 5 is finished. 55123 rows have been exported.
# INFO:root:Export for state IN at industry level 6 is finished. 60246 rows have been exported.
# INFO:root:Export for state WI at industry level 2 is finished. 9115 rows have been exported.
# INFO:root:Export for state WI at industry level 5 is finished. 57193 rows have been exported.
# INFO:root:Export for state WI at industry level 6 is finished. 62254 rows have been exported.
# INFO:root:Export for state DC at industry level 2 is finished. 932 rows have been exported.
# INFO:root:Export for state DC at industry level 5 is finished. 4093 rows have been exported.
# INFO:root:Export for state DC at industry level 6 is finished. 4692 rows have been exported.
# INFO:root:Export for state LA at industry level 2 is finished. 6607 rows have been exported.
# INFO:root:Export for state LA at industry level 5 is finished. 37065 rows have been exported.
# INFO:root:Export for state LA at industry level 6 is finished. 40463 rows have been exported.
# INFO:root:Export for state HI at industry level 2 is finished. 1237 rows have been exported.
# INFO:root:Export for state HI at industry level 5 is finished. 8593 rows have been exported.
# INFO:root:Export for state HI at industry level 6 is finished. 9484 rows have been exported.
# INFO:root:Export for state PA at industry level 2 is finished. 18763 rows have been exported.
# INFO:root:Export for state PA at industry level 5 is finished. 114373 rows have been exported.
# INFO:root:Export for state PA at industry level 6 is finished. 124788 rows have been exported.
# INFO:root:Export for state IA at industry level 2 is finished. 8494 rows have been exported.
# INFO:root:Export for state IA at industry level 5 is finished. 38420 rows have been exported.
# INFO:root:Export for state IA at industry level 6 is finished. 40902 rows have been exported.
# INFO:root:Export for state SC at industry level 2 is finished. 5267 rows have been exported.
# INFO:root:Export for state SC at industry level 5 is finished. 34518 rows have been exported.
# INFO:root:Export for state SC at industry level 6 is finished. 37945 rows have been exported.
# INFO:root:Export for state TN at industry level 2 is finished. 7199 rows have been exported.
# INFO:root:Export for state TN at industry level 5 is finished. 46056 rows have been exported.
# INFO:root:Export for state TN at industry level 6 is finished. 50306 rows have been exported.
# INFO:root:Export for state ND at industry level 2 is finished. 2926 rows have been exported.
# INFO:root:Export for state ND at industry level 5 is finished. 10622 rows have been exported.
# INFO:root:Export for state ND at industry level 6 is finished. 11279 rows have been exported.
# INFO:root:Export for state AL at industry level 2 is finished. 7221 rows have been exported.
# INFO:root:Export for state AL at industry level 5 is finished. 39129 rows have been exported.
# INFO:root:Export for state AL at industry level 6 is finished. 42267 rows have been exported.
# INFO:root:Export for state IL at industry level 2 is finished. 14312 rows have been exported.
# INFO:root:Export for state IL at industry level 5 is finished. 99569 rows have been exported.
# INFO:root:Export for state IL at industry level 6 is finished. 110022 rows have been exported.
# INFO:root:Export for state NY at industry level 2 is finished. 20774 rows have been exported.
# INFO:root:Export for state NY at industry level 5 is finished. 144799 rows have been exported.
# INFO:root:Export for state NY at industry level 6 is finished. 160171 rows have been exported.
# INFO:root:Export for state MT at industry level 2 is finished. 3029 rows have been exported.
# INFO:root:Export for state MT at industry level 5 is finished. 13992 rows have been exported.
# INFO:root:Export for state MT at industry level 6 is finished. 15166 rows have been exported.
# INFO:root:Export for state MI at industry level 2 is finished. 11925 rows have been exported.
# INFO:root:Export for state MI at industry level 5 is finished. 81908 rows have been exported.
# INFO:root:Export for state MI at industry level 6 is finished. 90200 rows have been exported.
# INFO:root:Export for state NJ at industry level 2 is finished. 8603 rows have been exported.
# INFO:root:Export for state NJ at industry level 5 is finished. 74496 rows have been exported.
# INFO:root:Export for state NJ at industry level 6 is finished. 82709 rows have been exported.
# INFO:root:Export for state WY at industry level 2 is finished. 1540 rows have been exported.
# INFO:root:Export for state WY at industry level 5 is finished. 7913 rows have been exported.
# INFO:root:Export for state WY at industry level 6 is finished. 8606 rows have been exported.
# INFO:root:Export for state MS at industry level 2 is finished. 4808 rows have been exported.
# INFO:root:Export for state MS at industry level 5 is finished. 23928 rows have been exported.
# INFO:root:Export for state MS at industry level 6 is finished. 25804 rows have been exported.
# INFO:root:Export for state DE at industry level 2 is finished. 918 rows have been exported.
# INFO:root:Export for state DE at industry level 5 is finished. 7376 rows have been exported.
# INFO:root:Export for state DE at industry level 6 is finished. 8203 rows have been exported.
# INFO:root:Export for state MO at industry level 2 is finished. 9724 rows have been exported.
# INFO:root:Export for state MO at industry level 5 is finished. 55120 rows have been exported.
# INFO:root:Export for state MO at industry level 6 is finished. 59978 rows have been exported.
# INFO:root:Export for state NM at industry level 2 is finished. 2903 rows have been exported.
# INFO:root:Export for state NM at industry level 5 is finished. 14851 rows have been exported.
# INFO:root:Export for state NM at industry level 6 is finished. 16359 rows have been exported.
# INFO:root:Export for state VA at industry level 2 is finished. 10285 rows have been exported.
# INFO:root:Export for state VA at industry level 5 is finished. 62167 rows have been exported.
# INFO:root:Export for state VA at industry level 6 is finished. 68673 rows have been exported.
# INFO:root:Export for state OR at industry level 2 is finished. 4792 rows have been exported.
# INFO:root:Export for state OR at industry level 5 is finished. 34305 rows have been exported.
# INFO:root:Export for state OR at industry level 6 is finished. 38072 rows have been exported.
# INFO:root:Total rows exported for Year 2013: 5565493
# INFO:root:Export for state RI at industry level 2 is finished. 1072 rows have been exported.
# INFO:root:Export for state RI at industry level 5 is finished. 9326 rows have been exported.
# INFO:root:Export for state RI at industry level 6 is finished. 10318 rows have been exported.
# INFO:root:Export for state SD at industry level 2 is finished. 2887 rows have been exported.
# INFO:root:Export for state SD at industry level 5 is finished. 11836 rows have been exported.
# INFO:root:Export for state SD at industry level 6 is finished. 12661 rows have been exported.
# INFO:root:Export for state CA at industry level 2 is finished. 25876 rows have been exported.
# INFO:root:Export for state CA at industry level 5 is finished. 225684 rows have been exported.
# INFO:root:Export for state CA at industry level 6 is finished. 254658 rows have been exported.
# INFO:root:Export for state MA at industry level 2 is finished. 7763 rows have been exported.
# INFO:root:Export for state MA at industry level 5 is finished. 60123 rows have been exported.
# INFO:root:Export for state MA at industry level 6 is finished. 66478 rows have been exported.
# INFO:root:Export for state CT at industry level 2 is finished. 4183 rows have been exported.
# INFO:root:Export for state CT at industry level 5 is finished. 31301 rows have been exported.
# INFO:root:Export for state CT at industry level 6 is finished. 34550 rows have been exported.
# INFO:root:Export for state WA at industry level 2 is finished. 7447 rows have been exported.
# INFO:root:Export for state WA at industry level 5 is finished. 55385 rows have been exported.
# INFO:root:Export for state WA at industry level 6 is finished. 61702 rows have been exported.
# INFO:root:Export for state NH at industry level 2 is finished. 2988 rows have been exported.
# INFO:root:Export for state NH at industry level 5 is finished. 16171 rows have been exported.
# INFO:root:Export for state NH at industry level 6 is finished. 17587 rows have been exported.
# INFO:root:Export for state KY at industry level 2 is finished. 6654 rows have been exported.
# INFO:root:Export for state KY at industry level 5 is finished. 34489 rows have been exported.
# INFO:root:Export for state KY at industry level 6 is finished. 37497 rows have been exported.
# INFO:root:Export for state GA at industry level 2 is finished. 9409 rows have been exported.
# INFO:root:Export for state GA at industry level 5 is finished. 66456 rows have been exported.
# INFO:root:Export for state GA at industry level 6 is finished. 73525 rows have been exported.
# INFO:root:Export for state ME at industry level 2 is finished. 4324 rows have been exported.
# INFO:root:Export for state ME at industry level 5 is finished. 18851 rows have been exported.
# INFO:root:Export for state ME at industry level 6 is finished. 20201 rows have been exported.
# INFO:root:Export for state NV at industry level 2 is finished. 2369 rows have been exported.
# INFO:root:Export for state NV at industry level 5 is finished. 17443 rows have been exported.
# INFO:root:Export for state NV at industry level 6 is finished. 19538 rows have been exported.
# INFO:root:Export for state UT at industry level 2 is finished. 3049 rows have been exported.
# INFO:root:Export for state UT at industry level 5 is finished. 22431 rows have been exported.
# INFO:root:Export for state UT at industry level 6 is finished. 25174 rows have been exported.
# INFO:root:Export for state MO at industry level 2 is finished. 9758 rows have been exported.
# INFO:root:Export for state MO at industry level 5 is finished. 54947 rows have been exported.
# INFO:root:Export for state MO at industry level 6 is finished. 59799 rows have been exported.
# INFO:root:Export for state NM at industry level 2 is finished. 2901 rows have been exported.
# INFO:root:Export for state NM at industry level 5 is finished. 14719 rows have been exported.
# INFO:root:Export for state NM at industry level 6 is finished. 16268 rows have been exported.
# INFO:root:Export for state VA at industry level 2 is finished. 10302 rows have been exported.
# INFO:root:Export for state VA at industry level 5 is finished. 62072 rows have been exported.
# INFO:root:Export for state VA at industry level 6 is finished. 68626 rows have been exported.
# INFO:root:Export for state OR at industry level 2 is finished. 4823 rows have been exported.
# INFO:root:Export for state OR at industry level 5 is finished. 34477 rows have been exported.
# INFO:root:Export for state OR at industry level 6 is finished. 38258 rows have been exported.
# INFO:root:Export for state TX at industry level 2 is finished. 25200 rows have been exported.
# INFO:root:Export for state TX at industry level 5 is finished. 174446 rows have been exported.
# INFO:root:Export for state TX at industry level 6 is finished. 193174 rows have been exported.
# INFO:root:Export for state WV at industry level 2 is finished. 4852 rows have been exported.
# INFO:root:Export for state WV at industry level 5 is finished. 17582 rows have been exported.
# INFO:root:Export for state WV at industry level 6 is finished. 18805 rows have been exported.
# INFO:root:Export for state AR at industry level 2 is finished. 5336 rows have been exported.
# INFO:root:Export for state AR at industry level 5 is finished. 25756 rows have been exported.
# INFO:root:Export for state AR at industry level 6 is finished. 27777 rows have been exported.
# INFO:root:Export for state FL at industry level 2 is finished. 16230 rows have been exported.
# INFO:root:Export for state FL at industry level 5 is finished. 145426 rows have been exported.
# INFO:root:Export for state FL at industry level 6 is finished. 163718 rows have been exported.
# INFO:root:Export for state AK at industry level 2 is finished. 1716 rows have been exported.
# INFO:root:Export for state AK at industry level 5 is finished. 7678 rows have been exported.
# INFO:root:Export for state AK at industry level 6 is finished. 8354 rows have been exported.
# INFO:root:Export for state VT at industry level 2 is finished. 2667 rows have been exported.
# INFO:root:Export for state VT at industry level 5 is finished. 10836 rows have been exported.
# INFO:root:Export for state VT at industry level 6 is finished. 11527 rows have been exported.
# INFO:root:Export for state NotSpecified at industry level 2 is finished. 17 rows have been exported.
# INFO:root:Export for state NotSpecified at industry level 5 is finished. 250 rows have been exported.
# INFO:root:Export for state NotSpecified at industry level 6 is finished. 297 rows have been exported.
# INFO:root:Export for state ID at industry level 2 is finished. 2746 rows have been exported.
# INFO:root:Export for state ID at industry level 5 is finished. 15769 rows have been exported.
# INFO:root:Export for state ID at industry level 6 is finished. 17340 rows have been exported.
# INFO:root:Export for state OK at industry level 2 is finished. 6682 rows have been exported.
# INFO:root:Export for state OK at industry level 5 is finished. 35304 rows have been exported.
# INFO:root:Export for state OK at industry level 6 is finished. 38337 rows have been exported.
# INFO:root:Export for state NC at industry level 2 is finished. 10962 rows have been exported.
# INFO:root:Export for state NC at industry level 5 is finished. 73486 rows have been exported.
# INFO:root:Export for state NC at industry level 6 is finished. 80822 rows have been exported.
# INFO:root:Export for state MN at industry level 2 is finished. 9369 rows have been exported.
# INFO:root:Export for state MN at industry level 5 is finished. 58159 rows have been exported.
# INFO:root:Export for state MN at industry level 6 is finished. 63441 rows have been exported.
# INFO:root:Export for state KS at industry level 2 is finished. 6499 rows have been exported.
# INFO:root:Export for state KS at industry level 5 is finished. 31515 rows have been exported.
# INFO:root:Export for state KS at industry level 6 is finished. 34028 rows have been exported.
# INFO:root:Export for state AL at industry level 2 is finished. 7216 rows have been exported.
# INFO:root:Export for state AL at industry level 5 is finished. 38872 rows have been exported.
# INFO:root:Export for state AL at industry level 6 is finished. 41996 rows have been exported.
# INFO:root:Export for state IL at industry level 2 is finished. 14306 rows have been exported.
# INFO:root:Export for state IL at industry level 5 is finished. 99184 rows have been exported.
# INFO:root:Export for state IL at industry level 6 is finished. 109676 rows have been exported.
# INFO:root:Export for state NY at industry level 2 is finished. 20831 rows have been exported.
# INFO:root:Export for state NY at industry level 5 is finished. 144863 rows have been exported.
# INFO:root:Export for state NY at industry level 6 is finished. 160279 rows have been exported.
# INFO:root:Export for state MT at industry level 2 is finished. 3057 rows have been exported.
# INFO:root:Export for state MT at industry level 5 is finished. 14038 rows have been exported.
# INFO:root:Export for state MT at industry level 6 is finished. 15206 rows have been exported.
# INFO:root:Export for state MI at industry level 2 is finished. 11970 rows have been exported.
# INFO:root:Export for state MI at industry level 5 is finished. 81893 rows have been exported.
# INFO:root:Export for state MI at industry level 6 is finished. 90290 rows have been exported.
# INFO:root:Export for state NJ at industry level 2 is finished. 8603 rows have been exported.
# INFO:root:Export for state NJ at industry level 5 is finished. 74160 rows have been exported.
# INFO:root:Export for state NJ at industry level 6 is finished. 82387 rows have been exported.
# INFO:root:Export for state WY at industry level 2 is finished. 1554 rows have been exported.
# INFO:root:Export for state WY at industry level 5 is finished. 7922 rows have been exported.
# INFO:root:Export for state WY at industry level 6 is finished. 8600 rows have been exported.
# INFO:root:Export for state MS at industry level 2 is finished. 4806 rows have been exported.
# INFO:root:Export for state MS at industry level 5 is finished. 23779 rows have been exported.
# INFO:root:Export for state MS at industry level 6 is finished. 25653 rows have been exported.
# INFO:root:Export for state DE at industry level 2 is finished. 923 rows have been exported.
# INFO:root:Export for state DE at industry level 5 is finished. 7402 rows have been exported.
# INFO:root:Export for state DE at industry level 6 is finished. 8225 rows have been exported.
# INFO:root:Export for state PA at industry level 2 is finished. 18834 rows have been exported.
# INFO:root:Export for state PA at industry level 5 is finished. 114224 rows have been exported.
# INFO:root:Export for state PA at industry level 6 is finished. 124640 rows have been exported.
# INFO:root:Export for state IA at industry level 2 is finished. 8474 rows have been exported.
# INFO:root:Export for state IA at industry level 5 is finished. 38244 rows have been exported.
# INFO:root:Export for state IA at industry level 6 is finished. 40697 rows have been exported.
# INFO:root:Export for state SC at industry level 2 is finished. 5278 rows have been exported.
# INFO:root:Export for state SC at industry level 5 is finished. 34471 rows have been exported.
# INFO:root:Export for state SC at industry level 6 is finished. 37918 rows have been exported.
# INFO:root:Export for state TN at industry level 2 is finished. 7221 rows have been exported.
# INFO:root:Export for state TN at industry level 5 is finished. 45786 rows have been exported.
# INFO:root:Export for state TN at industry level 6 is finished. 50053 rows have been exported.
# INFO:root:Export for state ND at industry level 2 is finished. 2948 rows have been exported.
# INFO:root:Export for state ND at industry level 5 is finished. 10636 rows have been exported.
# INFO:root:Export for state ND at industry level 6 is finished. 11304 rows have been exported.
# INFO:root:Export for state MD at industry level 2 is finished. 5688 rows have been exported.
# INFO:root:Export for state MD at industry level 5 is finished. 40865 rows have been exported.
# INFO:root:Export for state MD at industry level 6 is finished. 45553 rows have been exported.
# INFO:root:Export for state CO at industry level 2 is finished. 6302 rows have been exported.
# INFO:root:Export for state CO at industry level 5 is finished. 45684 rows have been exported.
# INFO:root:Export for state CO at industry level 6 is finished. 51098 rows have been exported.
# INFO:root:Export for state AZ at industry level 2 is finished. 5311 rows have been exported.
# INFO:root:Export for state AZ at industry level 5 is finished. 39646 rows have been exported.
# INFO:root:Export for state AZ at industry level 6 is finished. 44421 rows have been exported.
# INFO:root:Export for state OH at industry level 2 is finished. 13239 rows have been exported.
# INFO:root:Export for state OH at industry level 5 is finished. 91600 rows have been exported.
# INFO:root:Export for state OH at industry level 6 is finished. 100694 rows have been exported.
# INFO:root:Export for state NE at industry level 2 is finished. 5072 rows have been exported.
# INFO:root:Export for state NE at industry level 5 is finished. 23093 rows have been exported.
# INFO:root:Export for state NE at industry level 6 is finished. 24806 rows have been exported.
# INFO:root:Export for state IN at industry level 2 is finished. 8573 rows have been exported.
# INFO:root:Export for state IN at industry level 5 is finished. 54921 rows have been exported.
# INFO:root:Export for state IN at industry level 6 is finished. 60094 rows have been exported.
# INFO:root:Export for state WI at industry level 2 is finished. 9136 rows have been exported.
# INFO:root:Export for state WI at industry level 5 is finished. 57098 rows have been exported.
# INFO:root:Export for state WI at industry level 6 is finished. 62164 rows have been exported.
# INFO:root:Export for state DC at industry level 2 is finished. 930 rows have been exported.
# INFO:root:Export for state DC at industry level 5 is finished. 4123 rows have been exported.
# INFO:root:Export for state DC at industry level 6 is finished. 4718 rows have been exported.
# INFO:root:Export for state LA at industry level 2 is finished. 6613 rows have been exported.
# INFO:root:Export for state LA at industry level 5 is finished. 36976 rows have been exported.
# INFO:root:Export for state LA at industry level 6 is finished. 40414 rows have been exported.
# INFO:root:Export for state HI at industry level 2 is finished. 1237 rows have been exported.
# INFO:root:Export for state HI at industry level 5 is finished. 8563 rows have been exported.
# INFO:root:Export for state HI at industry level 6 is finished. 9459 rows have been exported.
# INFO:root:Total rows exported for Year 2014: 5570969
# INFO:root:Export for state RI at industry level 2 is finished. 1076 rows have been exported.
# INFO:root:Export for state RI at industry level 5 is finished. 9372 rows have been exported.
# INFO:root:Export for state RI at industry level 6 is finished. 10351 rows have been exported.
# INFO:root:Export for state SD at industry level 2 is finished. 2887 rows have been exported.
# INFO:root:Export for state SD at industry level 5 is finished. 11888 rows have been exported.
# INFO:root:Export for state SD at industry level 6 is finished. 12726 rows have been exported.
# INFO:root:Export for state CA at industry level 2 is finished. 25841 rows have been exported.
# INFO:root:Export for state CA at industry level 5 is finished. 226899 rows have been exported.
# INFO:root:Export for state CA at industry level 6 is finished. 256407 rows have been exported.
# INFO:root:Export for state MA at industry level 2 is finished. 7772 rows have been exported.
# INFO:root:Export for state MA at industry level 5 is finished. 60089 rows have been exported.
# INFO:root:Export for state MA at industry level 6 is finished. 66464 rows have been exported.
# INFO:root:Export for state CT at industry level 2 is finished. 4205 rows have been exported.
# INFO:root:Export for state CT at industry level 5 is finished. 31243 rows have been exported.
# INFO:root:Export for state CT at industry level 6 is finished. 34550 rows have been exported.
# INFO:root:Export for state WA at industry level 2 is finished. 7455 rows have been exported.
# INFO:root:Export for state WA at industry level 5 is finished. 55651 rows have been exported.
# INFO:root:Export for state WA at industry level 6 is finished. 62035 rows have been exported.
# INFO:root:Export for state NH at industry level 2 is finished. 3011 rows have been exported.
# INFO:root:Export for state NH at industry level 5 is finished. 16198 rows have been exported.
# INFO:root:Export for state NH at industry level 6 is finished. 17609 rows have been exported.
# INFO:root:Export for state KY at industry level 2 is finished. 6637 rows have been exported.
# INFO:root:Export for state KY at industry level 5 is finished. 34391 rows have been exported.
# INFO:root:Export for state KY at industry level 6 is finished. 37383 rows have been exported.
# INFO:root:Export for state GA at industry level 2 is finished. 9463 rows have been exported.
# INFO:root:Export for state GA at industry level 5 is finished. 66819 rows have been exported.
# INFO:root:Export for state GA at industry level 6 is finished. 73995 rows have been exported.
# INFO:root:Export for state ME at industry level 2 is finished. 4371 rows have been exported.
# INFO:root:Export for state ME at industry level 5 is finished. 18949 rows have been exported.
# INFO:root:Export for state ME at industry level 6 is finished. 20320 rows have been exported.
# INFO:root:Export for state NV at industry level 2 is finished. 2362 rows have been exported.
# INFO:root:Export for state NV at industry level 5 is finished. 17614 rows have been exported.
# INFO:root:Export for state NV at industry level 6 is finished. 19769 rows have been exported.
# INFO:root:Export for state UT at industry level 2 is finished. 3054 rows have been exported.
# INFO:root:Export for state UT at industry level 5 is finished. 22717 rows have been exported.
# INFO:root:Export for state UT at industry level 6 is finished. 25562 rows have been exported.
# INFO:root:Export for state TX at industry level 2 is finished. 25374 rows have been exported.
# INFO:root:Export for state TX at industry level 5 is finished. 175891 rows have been exported.
# INFO:root:Export for state TX at industry level 6 is finished. 194911 rows have been exported.
# INFO:root:Export for state WV at industry level 2 is finished. 4845 rows have been exported.
# INFO:root:Export for state WV at industry level 5 is finished. 17461 rows have been exported.
# ...
# INFO:root:Export for state FL at industry level 6 is finished. 56937 rows have been exported.
# INFO:root:Export for state VT at industry level 2 is finished. 1361 rows have been exported.
# INFO:root:Export for state VT at industry level 5 is finished. 1698 rows have been exported.
# INFO:root:Export for state VT at industry level 6 is finished. 1658 rows have been exported.
# INFO:root:Export for state AR at industry level 2 is finished. 2919 rows have been exported.
# INFO:root:Export for state AR at industry level 5 is finished. 5896 rows have been exported.
# INFO:root:Export for state AR at industry level 6 is finished. 5939 rows have been exported.
# INFO:root:Export for state AK at industry level 2 is finished. 877 rows have been exported.
# INFO:root:Export for state AK at industry level 5 is finished. 2006 rows have been exported.
# INFO:root:Export for state AK at industry level 6 is finished. 2042 rows have been exported.
# INFO:root:Export for state NotSpecified at industry level 2 is finished. 17 rows have been exported.
# INFO:root:Export for state NotSpecified at industry level 5 is finished. 227 rows have been exported.
# INFO:root:Export for state NotSpecified at industry level 6 is finished. 264 rows have been exported.
# INFO:root:Total rows exported for Year 2021: 1682249
# INFO:root:Export for state KS at industry level 2 is finished. 3580 rows have been exported.
# INFO:root:Export for state KS at industry level 5 is finished. 6688 rows have been exported.
# INFO:root:Export for state KS at industry level 6 is finished. 6744 rows have been exported.
# INFO:root:Export for state MN at industry level 2 is finished. 5916 rows have been exported.
# INFO:root:Export for state MN at industry level 5 is finished. 14188 rows have been exported.
# INFO:root:Export for state MN at industry level 6 is finished. 14433 rows have been exported.
# INFO:root:Export for state OK at industry level 2 is finished. 3919 rows have been exported.
# INFO:root:Export for state OK at industry level 5 is finished. 8552 rows have been exported.
# INFO:root:Export for state OK at industry level 6 is finished. 8649 rows have been exported.
# INFO:root:Export for state NC at industry level 2 is finished. 7147 rows have been exported.
# INFO:root:Export for state NC at industry level 5 is finished. 22529 rows have been exported.
# INFO:root:Export for state NC at industry level 6 is finished. 23230 rows have been exported.
# INFO:root:Export for state ID at industry level 2 is finished. 1721 rows have been exported.
# INFO:root:Export for state ID at industry level 5 is finished. 5034 rows have been exported.
# INFO:root:Export for state ID at industry level 6 is finished. 5158 rows have been exported.
# INFO:root:Export for state TX at industry level 2 is finished. 17112 rows have been exported.
# INFO:root:Export for state TX at industry level 5 is finished. 56450 rows have been exported.
# INFO:root:Export for state TX at industry level 6 is finished. 58694 rows have been exported.
# INFO:root:Export for state WV at industry level 2 is finished. 2283 rows have been exported.
# INFO:root:Export for state WV at industry level 5 is finished. 2924 rows have been exported.
# INFO:root:Export for state WV at industry level 6 is finished. 2876 rows have been exported.
# INFO:root:Export for state FL at industry level 2 is finished. 11984 rows have been exported.
# INFO:root:Export for state FL at industry level 5 is finished. 55851 rows have been exported.
# INFO:root:Export for state FL at industry level 6 is finished. 58454 rows have been exported.
# INFO:root:Export for state VT at industry level 2 is finished. 1356 rows have been exported.
# INFO:root:Export for state VT at industry level 5 is finished. 1683 rows have been exported.
# INFO:root:Export for state VT at industry level 6 is finished. 1680 rows have been exported.
# INFO:root:Export for state AR at industry level 2 is finished. 2909 rows have been exported.
# INFO:root:Export for state AR at industry level 5 is finished. 6069 rows have been exported.
# INFO:root:Export for state AR at industry level 6 is finished. 6109 rows have been exported.
# INFO:root:Export for state AK at industry level 2 is finished. 899 rows have been exported.
# INFO:root:Export for state AK at industry level 5 is finished. 2010 rows have been exported.
# INFO:root:Export for state AK at industry level 6 is finished. 2058 rows have been exported.
# INFO:root:Export for state NotSpecified at industry level 2 is finished. 17 rows have been exported.
# INFO:root:Export for state NotSpecified at industry level 5 is finished. 228 rows have been exported.
# INFO:root:Export for state NotSpecified at industry level 6 is finished. 268 rows have been exported.
# INFO:root:Export for state CA at industry level 2 is finished. 17960 rows have been exported.
# INFO:root:Export for state CA at industry level 5 is finished. 85185 rows have been exported.
# INFO:root:Export for state CA at industry level 6 is finished. 88938 rows have been exported.
# INFO:root:Export for state WA at industry level 2 is finished. 5096 rows have been exported.
# INFO:root:Export for state WA at industry level 5 is finished. 18104 rows have been exported.
# INFO:root:Export for state WA at industry level 6 is finished. 18847 rows have been exported.
# INFO:root:Export for state CT at industry level 2 is finished. 2949 rows have been exported.
# INFO:root:Export for state CT at industry level 5 is finished. 8348 rows have been exported.
# INFO:root:Export for state CT at industry level 6 is finished. 8415 rows have been exported.
# INFO:root:Export for state NV at industry level 2 is finished. 1604 rows have been exported.
# INFO:root:Export for state NV at industry level 5 is finished. 6684 rows have been exported.
# INFO:root:Export for state NV at industry level 6 is finished. 6934 rows have been exported.
# INFO:root:Export for state KY at industry level 2 is finished. 3580 rows have been exported.
# INFO:root:Export for state KY at industry level 5 is finished. 8352 rows have been exported.
# INFO:root:Export for state KY at industry level 6 is finished. 8455 rows have been exported.
# INFO:root:Export for state GA at industry level 2 is finished. 6342 rows have been exported.
# INFO:root:Export for state GA at industry level 5 is finished. 21785 rows have been exported.
# INFO:root:Export for state GA at industry level 6 is finished. 22721 rows have been exported.
# INFO:root:Export for state ME at industry level 2 is finished. 2487 rows have been exported.
# INFO:root:Export for state ME at industry level 5 is finished. 3747 rows have been exported.
# INFO:root:Export for state ME at industry level 6 is finished. 3779 rows have been exported.
# INFO:root:Export for state UT at industry level 2 is finished. 2096 rows have been exported.
# INFO:root:Export for state UT at industry level 5 is finished. 8241 rows have been exported.
# INFO:root:Export for state UT at industry level 6 is finished. 8632 rows have been exported.
# INFO:root:Export for state MA at industry level 2 is finished. 5679 rows have been exported.
# INFO:root:Export for state MA at industry level 5 is finished. 17072 rows have been exported.
# INFO:root:Export for state MA at industry level 6 is finished. 17393 rows have been exported.
# INFO:root:Export for state NH at industry level 2 is finished. 1905 rows have been exported.
# INFO:root:Export for state NH at industry level 5 is finished. 3464 rows have been exported.
# INFO:root:Export for state NH at industry level 6 is finished. 3495 rows have been exported.
# INFO:root:Export for state SD at industry level 2 is finished. 1461 rows have been exported.
# INFO:root:Export for state SD at industry level 5 is finished. 2483 rows have been exported.
# INFO:root:Export for state SD at industry level 6 is finished. 2489 rows have been exported.
# INFO:root:Export for state RI at industry level 2 is finished. 799 rows have been exported.
# INFO:root:Export for state RI at industry level 5 is finished. 2800 rows have been exported.
# INFO:root:Export for state RI at industry level 6 is finished. 2851 rows have been exported.
# INFO:root:Export for state OR at industry level 2 is finished. 3187 rows have been exported.
# INFO:root:Export for state OR at industry level 5 is finished. 10934 rows have been exported.
# INFO:root:Export for state OR at industry level 6 is finished. 11344 rows have been exported.
# INFO:root:Export for state MO at industry level 2 is finished. 5707 rows have been exported.
# INFO:root:Export for state MO at industry level 5 is finished. 13294 rows have been exported.
# INFO:root:Export for state MO at industry level 6 is finished. 13414 rows have been exported.
# INFO:root:Export for state VA at industry level 2 is finished. 6281 rows have been exported.
# INFO:root:Export for state VA at industry level 5 is finished. 17886 rows have been exported.
# INFO:root:Export for state VA at industry level 6 is finished. 18576 rows have been exported.
# INFO:root:Export for state NM at industry level 2 is finished. 1511 rows have been exported.
# INFO:root:Export for state NM at industry level 5 is finished. 3936 rows have been exported.
# INFO:root:Export for state NM at industry level 6 is finished. 4036 rows have been exported.
# INFO:root:Export for state NJ at industry level 2 is finished. 6560 rows have been exported.
# INFO:root:Export for state NJ at industry level 5 is finished. 21185 rows have been exported.
# INFO:root:Export for state NJ at industry level 6 is finished. 22166 rows have been exported.
# INFO:root:Export for state MS at industry level 2 is finished. 2708 rows have been exported.
# INFO:root:Export for state MS at industry level 5 is finished. 5343 rows have been exported.
# INFO:root:Export for state MS at industry level 6 is finished. 5354 rows have been exported.
# INFO:root:Export for state IL at industry level 2 is finished. 9106 rows have been exported.
# INFO:root:Export for state IL at industry level 5 is finished. 27437 rows have been exported.
# INFO:root:Export for state IL at industry level 6 is finished. 28244 rows have been exported.
# INFO:root:Export for state NY at industry level 2 is finished. 13852 rows have been exported.
# INFO:root:Export for state NY at industry level 5 is finished. 43049 rows have been exported.
# INFO:root:Export for state NY at industry level 6 is finished. 44725 rows have been exported.
# INFO:root:Export for state AL at industry level 2 is finished. 4416 rows have been exported.
# INFO:root:Export for state AL at industry level 5 is finished. 9257 rows have been exported.
# INFO:root:Export for state AL at industry level 6 is finished. 9280 rows have been exported.
# INFO:root:Export for state MI at industry level 2 is finished. 7899 rows have been exported.
# INFO:root:Export for state MI at industry level 5 is finished. 21013 rows have been exported.
# INFO:root:Export for state MI at industry level 6 is finished. 21055 rows have been exported.
# INFO:root:Export for state WY at industry level 2 is finished. 904 rows have been exported.
# INFO:root:Export for state WY at industry level 5 is finished. 2093 rows have been exported.
# INFO:root:Export for state WY at industry level 6 is finished. 2119 rows have been exported.
# INFO:root:Export for state DE at industry level 2 is finished. 685 rows have been exported.
# INFO:root:Export for state DE at industry level 5 is finished. 2565 rows have been exported.
# INFO:root:Export for state DE at industry level 6 is finished. 2679 rows have been exported.
# INFO:root:Export for state MT at industry level 2 is finished. 1672 rows have been exported.
# INFO:root:Export for state MT at industry level 5 is finished. 3581 rows have been exported.
# INFO:root:Export for state MT at industry level 6 is finished. 3648 rows have been exported.
# INFO:root:Export for state CO at industry level 2 is finished. 4289 rows have been exported.
# INFO:root:Export for state CO at industry level 5 is finished. 15794 rows have been exported.
# INFO:root:Export for state CO at industry level 6 is finished. 16429 rows have been exported.
# INFO:root:Export for state MD at industry level 2 is finished. 3957 rows have been exported.
# INFO:root:Export for state MD at industry level 5 is finished. 12693 rows have been exported.
# INFO:root:Export for state MD at industry level 6 is finished. 13104 rows have been exported.
# INFO:root:Export for state AZ at industry level 2 is finished. 3611 rows have been exported.
# INFO:root:Export for state AZ at industry level 5 is finished. 14103 rows have been exported.
# INFO:root:Export for state AZ at industry level 6 is finished. 14623 rows have been exported.
# INFO:root:Export for state WI at industry level 2 is finished. 5901 rows have been exported.
# INFO:root:Export for state WI at industry level 5 is finished. 13469 rows have been exported.
# INFO:root:Export for state WI at industry level 6 is finished. 13338 rows have been exported.
# INFO:root:Export for state LA at industry level 2 is finished. 3872 rows have been exported.
# INFO:root:Export for state LA at industry level 5 is finished. 9761 rows have been exported.
# INFO:root:Export for state LA at industry level 6 is finished. 9911 rows have been exported.
# INFO:root:Export for state NE at industry level 2 is finished. 2799 rows have been exported.
# INFO:root:Export for state NE at industry level 5 is finished. 5008 rows have been exported.
# INFO:root:Export for state NE at industry level 6 is finished. 4990 rows have been exported.
# INFO:root:Export for state IN at industry level 2 is finished. 5463 rows have been exported.
# INFO:root:Export for state IN at industry level 5 is finished. 14083 rows have been exported.
# INFO:root:Export for state IN at industry level 6 is finished. 14102 rows have been exported.
# INFO:root:Export for state DC at industry level 2 is finished. 469 rows have been exported.
# INFO:root:Export for state DC at industry level 5 is finished. 1645 rows have been exported.
# INFO:root:Export for state DC at industry level 6 is finished. 1771 rows have been exported.
# INFO:root:Export for state OH at industry level 2 is finished. 8752 rows have been exported.
# INFO:root:Export for state OH at industry level 5 is finished. 23445 rows have been exported.
# INFO:root:Export for state OH at industry level 6 is finished. 23483 rows have been exported.
# INFO:root:Export for state HI at industry level 2 is finished. 819 rows have been exported.
# INFO:root:Export for state HI at industry level 5 is finished. 2857 rows have been exported.
# INFO:root:Export for state HI at industry level 6 is finished. 2965 rows have been exported.
# INFO:root:Export for state PA at industry level 2 is finished. 11746 rows have been exported.
# INFO:root:Export for state PA at industry level 5 is finished. 27779 rows have been exported.
# INFO:root:Export for state PA at industry level 6 is finished. 28005 rows have been exported.
# INFO:root:Export for state ND at industry level 2 is finished. 1339 rows have been exported.
# INFO:root:Export for state ND at industry level 5 is finished. 2080 rows have been exported.
# INFO:root:Export for state ND at industry level 6 is finished. 2081 rows have been exported.
# INFO:root:Export for state TN at industry level 2 is finished. 4652 rows have been exported.
# INFO:root:Export for state TN at industry level 5 is finished. 13051 rows have been exported.
# INFO:root:Export for state TN at industry level 6 is finished. 13327 rows have been exported.
# INFO:root:Export for state SC at industry level 2 is finished. 3476 rows have been exported.
# INFO:root:Export for state SC at industry level 5 is finished. 10613 rows have been exported.
# INFO:root:Export for state SC at industry level 6 is finished. 10896 rows have been exported.
# INFO:root:Export for state IA at industry level 2 is finished. 4594 rows have been exported.
# INFO:root:Export for state IA at industry level 5 is finished. 7189 rows have been exported.
# INFO:root:Export for state IA at industry level 6 is finished. 7138 rows have been exported.
# INFO:root:Total rows exported for Year 2022: 1708747

# %%
def display_export_summary(export_results):
    """
    Displays the summary of export results for different years.

    Args:
        export_results (dict): A dictionary where keys are years and values are tuples of (industry_level_row_counts, total_rows_exported).
                               `industry_level_row_counts` is a dict with industry levels as keys and row counts as values.
                               `total_rows_exported` is the total number of rows exported for that year.
    """
    print("Export Summary:")
    print("-" * 50)
    
    for year, (industry_level_row_counts, total_rows_exported) in export_results.items():
        print(f"Year: {year}")
        for level, count in industry_level_row_counts.items():
            print(f"  Industry Level {level}: {count} rows")
        print(f"  Total Rows: {total_rows_exported}")
        print("-" * 50)

# %%
display_export_summary(export_results)

# %% [markdown]
# ## II. Tests After Export
#
# In this section, we will validate the consistency of the exported CSV files against the original DuckDB database. These tests will ensure that the exported files contain the expected data and accurately reflect the data from the database.
#
# The following tests will be performed:
# 1. Unit tests to ensure the functionality of the `DataExporter` is robust.
# 2. Validation to confirm that the data in the CSV files matches the data in the DuckDB database.

# %% [markdown]
# ### II.(a) Unit Test for Data Exporter Accuracy
#
# This section validates the accuracy of data exported by the `DataExporter` class. It ensures that the exported CSV files correctly reflect the data in the DuckDB database.
#
# #### Description
#
# The notebook performs the following tasks:
# - **Setup**: Creates a temporary DuckDB database with test data.
# - **Export**: Uses the `DataExporter` to generate CSV files.
# - **Validation**:
#   - Checks that the number of rows in the CSV files matches the database.
#   - Verifies that the data in the CSV files is consistent with the database.
# - **Teardown**: Removes test files and the temporary database.
#
# #### Key Tests
#
# - **Row Count Check**: Ensures that the number of rows in the exported CSV files matches those in the database.
# - **Data Consistency Check**: Confirms that the data values and types in the CSV files align with the database.
#
# #### Usage
#
# Execute the cells in the notebook to perform the tests. The notebook will automatically set up the test environment, run the validations, and clean up afterward.

# %%
# Execute the test script
# %run data_exporter_unit_test.py

# %% [markdown]
# ### II.(b) Data Export Validation Test
#
# This test ensures that the CSV files exported from our DuckDB database match the data stored in the database.
#
# **Description:**
# The `DataExporterTest` class validates the accuracy of exported CSV files by comparing them with the data in the DuckDB database. This process checks for consistency across all states and industry levels, ensuring that the exported files correctly represent the database records.
#
# **Key Tests:**
# 1. **Initialization:** Configure the `DataExporterTest` with the target year and directory paths.
# 2. **Data Fetching:** Retrieve data from the database for all states and industry levels.
# 3. **CSV Comparison:** Compare the contents of each CSV file with the corresponding database data.
# 4. **Mismatch Reporting:** Log any discrepancies with detailed information, including file paths and data previews.
#
# **Usage:**
# To run the test:
# 1. Initialize the `DataExporterTest` with the desired year and directory paths.
# 2. Execute the test script.
# 3. Review the logs for any discrepancies between the CSV files and the database data.
#
# The test will help ensure the integrity and accuracy of the exported data files.

# %%
from data_exporter_validation_test import DataExporterTest

# %% [markdown]
# #### Validate a Single Year：

# %%
# Replace '2019' with your desired year
# The default values for the Constructor's arguments are: 
# base_db_path='../zip_data/duck_db_manager/database/', export_dir='../../US/zip'
# Update these paths if any changes occur:
tester = DataExporterTest(year=2019) 
tester.run_test()
# Out:
# All CSV files match the database data by row count.

# %% [markdown]
# #### Validate for All Years:

# %%
for year in range(2012, 2023):
    tester = DataExporterTest(year=year)
    tester.run_test()
# Out:
# Tested Year {year}: All CSV files match the database data by row count.
# Tested Year {year}: All CSV files match the database data by row count.
# Tested Year {year}: All CSV files match the database data by row count.
# Tested Year {year}: All CSV files match the database data by row count.
# Tested Year {year}: All CSV files match the database data by row count.
# Tested Year {year}: All CSV files match the database data by row count.
# Tested Year {year}: All CSV files match the database data by row count.
# Tested Year {year}: All CSV files match the database data by row count.
# Tested Year {year}: All CSV files match the database data by row count.
# Tested Year {year}: All CSV files match the database data by row count.
# Tested Year {year}: All CSV files match the database data by row count.
